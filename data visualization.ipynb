# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline



from sklearn.model_selection import train_test_split
from sklearn import mixture
from sklearn.mixture import GaussianMixture as GMM
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
import zipfile
with zipfile.ZipFile('data/hackathon_kpis_anonymised.zip', 'r') as zip_ref:
    zip_ref.extractall('.')
    
df = pd.read_csv('hackathon_kpis_anonymised.csv')

# %% [markdown]
# simple preproccessing

# %%
df = df.sort_values(by = 'cell_name')
df = df.fillna(0.)
cell_occurrences = pd.DataFrame(df.cell_name.value_counts())
cell_occurrences.columns = ['count']

# %%
df.head(n=8)
# Out:
#        cell_name                  timestamp  ho_failure_rate  \
# 871505    00_11Q  2020-12-18 16:00:00+00:00         0.000000
# 697585    00_11Q  2020-03-19 20:00:00+00:00         0.000000
# 697584    00_11Q  2020-03-08 14:00:00+00:00         0.000000
# 697583    00_11Q  2020-03-07 09:00:00+00:00         0.000000
# 697582    00_11Q  2020-03-06 23:00:00+00:00         0.000000
# 697581    00_11Q  2020-02-02 21:00:00+00:00         0.000000
# 697580    00_11Q  2020-02-02 06:00:00+00:00         0.000000
# 697579    00_11Q  2020-01-29 20:00:00+00:00         0.333333
#
#         num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 871505            0.000000              0.0           0.011186
# 697585            0.000927              0.0           0.006195
# 697584            0.000000              0.0           0.000000
# 697583            0.000000              0.0           0.000000
# 697582            0.000000              0.0           0.000000
# 697581            0.001854              0.0           0.006871
# 697580            0.000000              0.0           0.005818
# 697579            0.006487              0.0           0.008539
#
#         voice_setup_failure_rate  voice_tot_failure_rate  \
# 871505                       0.0                     0.0
# 697585                       0.0                     0.0
# 697584                       0.0                     0.0
# 697583                       0.0                     0.0
# 697582                       0.0                     0.0
# 697581                       0.0                     0.0
# 697580                       0.0                     0.0
# 697579                       0.0                     0.0
#
#         avail_period_duration  bandwidth  throughput_rate  \
# 871505                    1.0    0.09955         0.000189
# 697585                    1.0    0.09955         0.000113
# 697584                    1.0    0.09955         0.000000
# 697583                    1.0    0.09955         0.000000
# 697582                    1.0    0.09955         0.000000
# 697581                    1.0    0.09955         0.000036
# 697580                    1.0    0.09955         0.000021
# 697579                    1.0    0.09955         0.000171
#
#         data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# 871505                 0.000592        0.000000               0.000074
# 697585                 0.002137        0.000000               0.000267
# 697584                 0.000000        0.000000               0.000000
# 697583                 0.000000        0.000000               0.000000
# 697582                 0.000000        0.000000               0.000000
# 697581                 0.000000        0.000241               0.000241
# 697580                 0.002275        0.000853               0.001138
# 697579                 0.004651        0.000000               0.000581
#
#         unavail_total_rate  unavail_unplan_rate
# 871505            0.333364                  0.0
# 697585            0.333364                  0.0
# 697584            0.666728                  0.0
# 697583            0.666728                  0.0
# 697582            0.666728                  0.0
# 697581            0.333364                  0.0
# 697580            0.333364                  0.0
# 697579            0.333364                  0.0
